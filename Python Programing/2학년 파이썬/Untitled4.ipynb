# %%
import pandas as pd

# %%
# !type ch06ex1.csv
# Out:
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
pd.read_csv('ch06ex1.csv',sep=',')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_csv('ch06ex1.csv',index_col='message')
# Out:
#          a   b   c   d
# message
# hello    1   2   3   4
# world    5   6   7   8
# foo      9  10  11  12

# %%
# !type ch06ex5.csv
# Out:
# 癤퓋omething,a,b,c,d,message
# one,1,2,3,4,NA
# two,5,6, ,8,world
# three,9,10,11,12,foo

# %%
result=pd.read_csv('ch06ex5.csv')
result
# Out:
#   something  a   b   c   d message
# 0       one  1   2   3   4     NaN
# 1       two  5   6       8   world
# 2     three  9  10  11  12     foo

# %%
pd.options.display.max_rows = 10

# %%
result = pd.read_csv('ch06ex6.csv')
result
# Out:
#      Unnamed: 0       one       two     three      four key
# 0           0.0  0.467976  0.375855  0.058720  0.054416   L
# 1           1.0  0.800079  0.825793  0.111016  0.139505   B
# 2           2.0  0.923957  0.373217  0.056069  0.368886   G
# 3           3.0  0.790325  0.696681  0.309395  0.862369   R
# 4           4.0  0.717920  0.504400  0.169551  0.357363   Q
# ..          ...       ...       ...       ...       ...  ..
# 97         97.0  0.793086  0.445337  0.804929  0.052003   B
# 98         98.0  0.070340  0.801364  0.013836  0.104213   B
# 99         99.0  0.052294  0.485987  0.849921 -0.028417   G
# 100         NaN       NaN       NaN       NaN       NaN
# 101         NaN       NaN       NaN       NaN       NaN
#
# [102 rows x 6 columns]

# %%
pd.read_csv('ch06ex6.csv', nrows=5)
# Out:
#    Unnamed: 0       one       two     three      four key
# 0           0  0.467976  0.375855  0.058720  0.054416   L
# 1           1  0.800079  0.825793  0.111016  0.139505   B
# 2           2  0.923957  0.373217  0.056069  0.368886   G
# 3           3  0.790325  0.696681  0.309395  0.862369   R
# 4           4  0.717920  0.504400  0.169551  0.357363   Q

# %%
chunker = pd.read_csv('ch06ex6.csv',chunksize=50)

# %%
chunker

# %%
tot=pd.Series([])
for piece in chunker:
    tot =tot.add(piece['key'].value_counts(),fill_value=0)
    
tot = tot.sort_values(ascending=False)
tot[:10]
# Out:
# G    20.0
# Q    19.0
# R    16.0
# B    15.0
# L    12.0
# U     5.0
# A     4.0
# K     2.0
# D     2.0
#       2.0
# dtype: float64

# %%
data = pd.read_csv('ch06ex5.csv')
data
# Out:
#   something  a   b   c   d message
# 0       one  1   2   3   4     NaN
# 1       two  5   6       8   world
# 2     three  9  10  11  12     foo

# %%
import sys

# %%
data.to_csv(sys.stdout,sep='|')
# Out:
# |something|a|b|c|d|message
# 0|one|1|2|3|4|
# 1|two|5|6| |8|world
# 2|three|9|10|11|12|foo

# %%
data.to_csv(sys.stdout,na_rep='NULL')
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3,4,NULL
# 1,two,5,6, ,8,world
# 2,three,9,10,11,12,foo

# %%
# !type ch06ex7.csv
# Out:
# ""a"",""b"",""c""
# ""1"",""2"",""3""
# ""1"",""2"",""3""

# %%
import csv
f = open('ch06ex7.csv', encoding = "utf-8")
reader = csv.reader(f)

# %%
for line in reader:
    print(line)
# Out:
# ['a""', 'b""', 'c""']
# ['1""', '2""', '3""']
# ['1""', '2""', '3""']

# %%
with open('ch06ex7.csv', encoding = 'utf-8') as f:
    lines = list(csv.reader(f))

# %%
header, valies = lines[0], lines[1:]

# %%
data_dict = {h:v for h ,v in zip(header, zip(*values))}
data_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-f8cd587e5023> in <module>
# ----> 1 data_dict = {h:v for h ,v in zip(header, zip(*values))}
#       2 data_dict
#
# NameError: name 'values' is not defined

# %%
df = pd.read_html('http://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table')

# %%
len(df)
# Out:
# 16

# %%
df
# Out:
# [                                       Olympic Games
#  0                                        Main topics
#  1  Bids Boycotts Ceremonies Charter Host cities I...
#  2                                              Games
#  3  Summer Winter Summer Paralympic Winter Paralym...
#  4                                                vte,
#                                 Unnamed: 0_level_0 Summer Games  \
#                                    Team (IOC code)            №
#  0                               Afghanistan (AFG)           14
#  1                                   Algeria (ALG)           13
#  2                                 Argentina (ARG)           24
#  3                                   Armenia (ARM)            6
#  4                         Australasia (ANZ) [ANZ]            2
#  ..                                            ...          ...
#  148      Independent Olympic Athletes (IOA) [IOA]            3
#  149  Independent Olympic Participants (IOP) [IOP]            1
# ...

# %%
df = pd.read_html('http://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table',header=0, index_col=0)
df[1]
# Out:
#                                              Summer Games  Summer Games.1  \
# Team (IOC code)                                         №             NaN
# Afghanistan (AFG)                                      14             0.0
# Algeria (ALG)                                          13             5.0
# Argentina (ARG)                                        24            21.0
# Armenia (ARM)                                           6             2.0
# ...                                                   ...             ...
# Independent Olympic Athletes (IOA) [IOA]                3             1.0
# Independent Olympic Participants (IOP) [IOP]            1             0.0
# Olympic Athletes from Russia (OAR) [OAR]                0             0.0
# Mixed team (ZZX) [ZZX]                                  3             8.0
# Totals                                                 28          5115.0
#
#                                               Summer Games.2  Summer Games.3  \
# ...

# %%
df[2]
# Out:
#                                   № Summer  № Winter  № Games
# Team (IOC code)
# Albania (ALB)                            8         4       12
# American Samoa (ASA)                     8         1        9
# Andorra (AND)                           11        12       23
# Angola (ANG)                             9         0        9
# Antigua and Barbuda (ANT)               10         0       10
# ...                                    ...       ...      ...
# Republic of China (ROC) [ROC]            3         0        3
# Saar (SAA) [SAA]                         1         0        1
# North Yemen (YAR) [YAR]                  2         0        2
# South Yemen (YMD) [YMD]                  1         0        1
# Refugee Olympic Team (ROT) [ROT]         1         0        1
#
# [79 rows x 3 columns]

# %%
df[3]
# Out:
#                              Summer Games  Summer Games.1  Summer Games.2  \
# Team (IOC code)                         №             NaN             NaN
# Germany (GER)                          16           191.0           194.0
# Saar (SAA)                              1             0.0             0.0
# United Team of Germany (EUA)            3            28.0            54.0
# East Germany (GDR)                      5           153.0           129.0
# West Germany (FRG)                      5            56.0            67.0
# Total                                  25           428.0           444.0
#
#                               Summer Games.3 Summer Games.4 Winter Games  \
# Team (IOC code)                          NaN          Total            №
# Germany (GER)                          230.0            615           12
# Saar (SAA)                               0.0              0            0
# United Team of Germany (EUA)            36.0            118            3
# ...

# %%
import sqlite3

# %%
query = """
CREATE TABLE
