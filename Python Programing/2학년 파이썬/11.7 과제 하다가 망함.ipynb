# %%
# %matplotlib notebook

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data = pd.read_csv('subwaytime.csv', encoding = 'cp949')
data
# Out:
#         사용월       호선명     역ID          지하철역 04:00:00~04:59:59 Unnamed: 5  \
# 0       NaN       NaN     NaN           NaN                승차         하차
# 1    Sep-19       1호선   150.0           서울역              959         20
# 2    Sep-19       1호선   151.0            시청               48          1
# 3    Sep-19       1호선   152.0            종각               96          3
# 4    Sep-19       1호선   153.0          종로3가              175          7
# 5    Sep-19       1호선   154.0          종로5가               34          0
# 6    Sep-19       1호선   155.0           동대문              563         12
# 7    Sep-19       1호선   156.0           신설동              328          5
# 8    Sep-19       1호선   157.0           제기동              359          3
# 9    Sep-19       1호선   158.0  청량리(서울시립대입구)             1284         13
# 10   Sep-19       1호선   159.0           동묘앞              127          3
# 11   Sep-19       2호선   201.0            시청               20          1
# ...

# %%
#tdata = pd.DataFrame(data).T
#tdata

# %%
df = data.iloc[1:597]
df
# Out:
#         사용월       호선명     역ID          지하철역 04:00:00~04:59:59 Unnamed: 5  \
# 1    Sep-19       1호선   150.0           서울역              959         20
# 2    Sep-19       1호선   151.0            시청               48          1
# 3    Sep-19       1호선   152.0            종각               96          3
# 4    Sep-19       1호선   153.0          종로3가              175          7
# 5    Sep-19       1호선   154.0          종로5가               34          0
# 6    Sep-19       1호선   155.0           동대문              563         12
# 7    Sep-19       1호선   156.0           신설동              328          5
# 8    Sep-19       1호선   157.0           제기동              359          3
# 9    Sep-19       1호선   158.0  청량리(서울시립대입구)             1284         13
# 10   Sep-19       1호선   159.0           동묘앞              127          3
# 11   Sep-19       2호선   201.0            시청               20          1
# 12   Sep-19       2호선   202.0         을지로입구               97          0
# ...

# %%
data[['호선명'04:00:00~04:59:59']]
# Out:
#   File "<ipython-input-199-373eb09ab54d>", line 1
#     data[['호선명'04:00:00~04:59:59']]
#                 ^
# SyntaxError: invalid token
