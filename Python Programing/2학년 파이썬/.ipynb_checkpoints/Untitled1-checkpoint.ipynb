# %%
set ([2,2,2,3,1,4,5,6])
Out[1]: {1, 2, 3, 4, 5, 6}

{2,2,3,4}
Out[2]: {2, 3, 4}

#107p부터 시작

a = {1,2,3,4,5}

b = {3,4,5,6,7,8}

a.union(b)
Out[6]: {1, 2, 3, 4, 5, 6, 7, 8}

a
Out[7]: {1, 2, 3, 4, 5}

b
Out[8]: {3, 4, 5, 6, 7, 8}

a|b
Out[9]: {1, 2, 3, 4, 5, 6, 7, 8}

a.intersection
Out[10]: <function set.intersection>

a.intersection(b)
Out[11]: {3, 4, 5}

a&b
Out[12]: {3, 4, 5}

a.add(6)

a
Out[14]: {1, 2, 3, 4, 5, 6}

a.clear()

a
Out[16]: set()

a = {1,2,3,4,5}

a.remove(5)

a
Out[19]: {1, 2, 3, 4}

a.remove(6)
Traceback (most recent call last):

  File "<ipython-input-20-b5608789f21a>", line 1, in <module>
    a.remove(6)

KeyError: 6




a.pop()
Out[21]: 1

a
Out[22]: {2, 3, 4}

a.add(1,5)
Traceback (most recent call last):

  File "<ipython-input-23-5880eec1310e>", line 1, in <module>
    a.add(1,5)

TypeError: add() takes exactly one argument (2 given)




#하나는 add가 되는데 두개는 ㄴㄴ

a
Out[25]: {2, 3, 4}

a.add(1)

a.add(5)

a
Out[28]: {1, 2, 3, 4, 5}

a.update(b)

a
Out[30]: {1, 2, 3, 4, 5, 6, 7, 8}

a = {1,2,3,4,5}

a&=b

a
Out[33]: {3, 4, 5}

a = a|b

a
Out[35]: {3, 4, 5, 6, 7, 8}

a = a&B
Traceback (most recent call last):

  File "<ipython-input-36-3932e027cabb>", line 1, in <module>
    a = a&B

NameError: name 'B' is not defined




a = a&b

a
Out[38]: {3, 4, 5, 6, 7, 8}

a
Out[39]: {3, 4, 5, 6, 7, 8}

a = {3,4,5}

b
Out[41]: {3, 4, 5, 6, 7, 8}

a.issubset(b)
Out[42]: True

c = a.copy()

c
Out[44]: {3, 4, 5}

a.add(1)

a.add(5)

c = a.copy()

c
Out[48]: {1, 3, 4, 5}

a
Out[49]: {1, 3, 4, 5}

a.add(2)

a
Out[51]: {1, 2, 3, 4, 5}

c = a.copy()

c
Out[53]: {1, 2, 3, 4, 5}

c |=b

c
Out[55]: {1, 2, 3, 4, 5, 6, 7, 8}

d = a

d
Out[57]: {1, 2, 3, 4, 5}

c
Out[58]: {1, 2, 3, 4, 5, 6, 7, 8}

d = d&c

d
Out[60]: {1, 2, 3, 4, 5}

d&=c

d
Out[62]: {1, 2, 3, 4, 5}

c
Out[63]: {1, 2, 3, 4, 5, 6, 7, 8}

d
Out[64]: {1, 2, 3, 4, 5}

c = {3,4,5,6,7,8}

d = d&c

d
Out[67]: {3, 4, 5}

d= a

b
Out[69]: {3, 4, 5, 6, 7, 8}

c
Out[70]: {3, 4, 5, 6, 7, 8}

d = d|c

d
Out[72]: {1, 2, 3, 4, 5, 6, 7, 8}

unique_lengths = {len(x) for x in strings}
Traceback (most recent call last):

  File "<ipython-input-73-aff1e9ac73ea>", line 1, in <module>
    unique_lengths = {len(x) for x in strings}

NameError: name 'strings' is not defined




#109p 부터

strings = ['a', 'as', 'bat', 'cat', 'dove', 'pyton']

[x.upper() for x strings if len(x)>2]
  File "<ipython-input-76-cafaf5dd1268>", line 1
    [x.upper() for x strings if len(x)>2]
                           ^
SyntaxError: invalid syntax




[x.upper() for x in strings if len(x) > 2]
Out[77]: ['BAT', 'CAT', 'DOVE', 'PYTON']

some_tuples = [(1,2,3,),(4,5,6)<(7,8,9)]

some_tuples = [(1,2,3,),(4,5,6)(7,8,9)]
Traceback (most recent call last):

  File "<ipython-input-79-351dbc5bf1ef>", line 1, in <module>
    some_tuples = [(1,2,3,),(4,5,6)(7,8,9)]

TypeError: 'tuple' object is not callable




some_tuples = [(1,2,3,),(4,5,6),(7,8,9)]

# %whos
Variable      Type    Data/Info
-------------------------------
a             set     {1, 2, 3, 4, 5}
b             set     {3, 4, 5, 6, 7, 8}
c             set     {3, 4, 5, 6, 7, 8}
d             set     {1, 2, 3, 4, 5, 6, 7, 8}
some_tuples   list    n=3
strings       list    n=6

flattened = [x for tup in some_tuples for x in tup]

def my_fn(x,y,z = 1.5):
    if z>1:
        return z*(x +y)
        else:
            return z/(x+y)
  File "<ipython-input-83-a736f573cd26>", line 4
    else:
       ^
SyntaxError: invalid syntax




def my_fn(x,y,z = 1.5):
    if z>1:
        return z*(x +y)
    else:
            return z/(x+y)
            

my_fn(5, 6, z = 0.7)
Out[85]: 0.06363636363636363

(3.14, 7, 3.5)
Out[86]: (3.14, 7, 3.5)

my_fn(3.14, 7, z = 3.5)
Out[87]: 35.49

my_fn(x = 5, y = 6, z = 7)
Out[88]: 77

my_fn(y = 6, x = 5, z = 7)
Out[89]: 77

my_fn(z = 7, x = 5, y = 6)
Out[90]: 77

#선언 할때는 초기값 인자가 뒤에 와야하지만 함수 사용할땐 앞에와도 ㄱㅊ

def func():
    a = []
    for i in rage(5):
        a.append(i)
        

a
Out[93]: {1, 2, 3, 4, 5}

#함수 내부에 a 를 선언 해서 a 가 위에 아까 만든 집합처럼 나오는 것

def f():
    a = 5
    b = 6
    c = 7
    return a,b,c
    

a,b,c = f()

return_value = f()

def short_function(x):
    return x*2
    

equiv_anon = lambda x: x*2

def apply_to_list(some_list, f):
    return [f(x) for x in some_list]
    

ints = [4,0,1,5,6]

apply_to_list(ints, lambda x: x*2)
Out[102]: [8, 0, 2, 10, 12]

strings = ['for', 'card','bar', 'aaaa', 'abab']

strings.sort(key = lambda x: len(set(list(x))))

set(list('aaaa'))
Out[105]: {'a'}
