# %%
from skimage import io
photo = io.imread('tree.jpg')
type(photo)
# Out:
# imageio.core.util.Array

# %%
photo.shape
# Out:
# (745, 500, 4)

# %%
import matplotlib.pyplot as plt
plt.imshow(photo)

# %%
plt.imshow(photo[::-1])

# %%
plt.imshow(photo[:,::-1])

# %%
plt.imshow(photo[50:150, 150:280])

# %%
plt.imshow(photo[::2,::2])

# %%
import numpy as np
photo
photo_sin = np.sin(photo)
photo_sin
# Out:
# Array([[[ 0.721  ,  0.8066 ,  0.9766 , -0.5063 ],
#         [ 0.721  ,  0.8066 ,  0.9766 , -0.5063 ],
#         [ 0.721  ,  0.8066 ,  0.9766 , -0.5063 ],
#         ...,
#         [ 0.9727 ,  0.796  , -0.9785 , -0.5063 ],
#         [-0.616  ,  0.796  , -0.9785 , -0.5063 ],
#         [-0.616  , -0.0795 , -0.355  , -0.5063 ]],
#
#        [[-0.1935 , -0.06192,  0.3467 , -0.5063 ],
#         [ 0.721  ,  0.8066 ,  0.3467 , -0.5063 ],
#         [ 0.9727 ,  0.8066 ,  0.3467 , -0.5063 ],
#         ...,
#         [ 0.33   , -0.0795 , -0.702  , -0.5063 ],
#         [-0.46   , -0.882  , -0.9785 , -0.5063 ],
#         [-0.46   , -0.8735 , -0.355  , -0.5063 ]],
#
#        [[ 0.721  , -0.06192,  0.3467 , -0.5063 ],
#         [ 0.9727 ,  0.8066 ,  0.3467 , -0.5063 ],
#         [ 0.9727 ,  0.8066 , -0.602  , -0.5063 ],
#         ...,
#         [-0.9956 , -0.8735 ,  0.2195 , -0.5063 ],
#         [ 0.4988 , -0.06192, -0.9785 , -0.5063 ],
#         [ 0.4988 , -0.06192, -0.9785 , -0.5063 ]],
#
# ...

# %%
print(np.sum(photo))
print(np.prod(photo))
print(np.mean(photo))
print(np.std(photo))
print(np.var(photo))
print(np.min(photo))
print(np.max(photo))
print(np.argmin(photo))
print(np.argmax(photo))
# Out:
# 231781724
# 0
# 155.55820402684563
# 76.82999327947918
# 5902.847867324816
# 0
# 255
# 274986
# 3

# %%
photo_masked = np.where(photo > 100,255,0)

# %%
plt.imshow(photo_masked)

# %%
photo_masked = np.where(photo > 50,255,0)
plt.imshow(photo_masked)

# %%
plt.imshow(photo[:,:,0].T)

# %%
import pandas as pd
##################과제 2번#########################

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table',header=0, index_col=0)

# %%
df[1]
# Out:
#                                              Summer Games  Summer Games.1  \
# Team (IOC code)                                         №             NaN
# Afghanistan (AFG)                                      14             0.0
# Algeria (ALG)                                          13             5.0
# Argentina (ARG)                                        24            21.0
# Armenia (ARM)                                           6             2.0
# Australasia (ANZ) [ANZ]                                 2             3.0
# Australia (AUS) [AUS] [Z]                              26           147.0
# Austria (AUT)                                          27            18.0
# Azerbaijan (AZE)                                        6             7.0
# Bahamas (BAH)                                          16             6.0
# Bahrain (BRN)                                           9             2.0
# Barbados (BAR) [BAR]                                   12             0.0
# ...

# %%
sdf= df[1]
adf = sdf[['Winter Games.1','Winter Games.2','Winter Games.3','Winter Games.4']]

# %%
adf
# Out:
#                                               Winter Games.1  Winter Games.2  \
# Team (IOC code)                                          NaN             NaN
# Afghanistan (AFG)                                        0.0             0.0
# Algeria (ALG)                                            0.0             0.0
# Argentina (ARG)                                          0.0             0.0
# Armenia (ARM)                                            0.0             0.0
# Australasia (ANZ) [ANZ]                                  0.0             0.0
# Australia (AUS) [AUS] [Z]                                5.0             5.0
# Austria (AUT)                                           64.0            81.0
# Azerbaijan (AZE)                                         0.0             0.0
# Bahamas (BAH)                                            0.0             0.0
# Bahrain (BRN)                                            0.0             0.0
# ...

# %%
adf.rename(columns={'Winter Games.1': '금', 'Winter Games.2': '은','Winter Games.3':'동','Winter Games.4':'합계'}, inplace=True)

# %%
adf
# Out:
#                                                    금       은       동     합계
# Team (IOC code)                                  NaN     NaN     NaN  Total
# Afghanistan (AFG)                                0.0     0.0     0.0      0
# Algeria (ALG)                                    0.0     0.0     0.0      0
# Argentina (ARG)                                  0.0     0.0     0.0      0
# Armenia (ARM)                                    0.0     0.0     0.0      0
# Australasia (ANZ) [ANZ]                          0.0     0.0     0.0      0
# Australia (AUS) [AUS] [Z]                        5.0     5.0     5.0     15
# Austria (AUT)                                   64.0    81.0    87.0    232
# Azerbaijan (AZE)                                 0.0     0.0     0.0      0
# Bahamas (BAH)                                    0.0     0.0     0.0      0
# Bahrain (BRN)                                    0.0     0.0     0.0      0
# ...

# %%
adf.sort_values(by=['금','은'], axis=0,ascending=False)
# Out:
#                                                    금       은       동     합계
# Totals                                        1062.0  1058.0  1050.0   3170
# Norway (NOR) [Q]                               132.0   125.0   111.0    368
# United States (USA) [P] [Q] [R] [Z]            105.0   112.0    88.0    305
# Germany (GER) [GER] [Z]                         92.0    88.0    60.0    240
# Soviet Union (URS) [URS]                        78.0    57.0    59.0    194
# Canada (CAN)                                    73.0    64.0    62.0    199
# Austria (AUT)                                   64.0    81.0    87.0    232
# Sweden (SWE) [Z]                                57.0    46.0    55.0    158
# Switzerland (SUI)                               56.0    45.0    52.0    153
# Russia (RUS) [RUS]                              47.0    38.0    35.0    120
# Netherlands (NED) [Z]                           45.0    44.0    41.0    130
# ...

# %%
import sqlite3

# %%
query = """
CREATE TABLE TEST
(a VARCHAR(20), b VARCHAR(20),
c REAL, d INTEGER
);"""

# %%
con = sqlite3.connect('mydata.sqlite')

# %%
con.execute(query)

# %%
con.commit()

# %%
data = [('Atlanta', 'Georgia', 1.25, 6),
       ('Tallahassee','Florida', 2.6, 4),
       ('Sacramento', 'California', 1.7, 5)]

# %%
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"

# %%
con.executemany(stmt, data)

# %%
con.commit()
