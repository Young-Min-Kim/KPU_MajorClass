# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
import numpy as np
# %matplotlib inline

# %%
sub = pd.read_csv('subwaystation.csv', encoding = 'cp949', thousands=',')
sub
# Out:
#          사용월       호선명   역ID          지하철역    승차승객수    하차승객수  \
# 0    2019-09       1호선   150           서울역  1635540  1556046
# 1    2019-09       1호선   151            시청   722697   734164
# 2    2019-09       1호선   152            종각  1194289  1152980
# 3    2019-09       1호선   153          종로3가   945508   883926
# 4    2019-09       1호선   154          종로5가   742255   744764
# 5    2019-09       1호선   155           동대문   435482   480671
# 6    2019-09       1호선   156           신설동   458094   444648
# 7    2019-09       1호선   157           제기동   597284   612842
# 8    2019-09       1호선   158  청량리(서울시립대입구)   737614   757914
# 9    2019-09       1호선   159           동묘앞   317196   333667
# 10   2019-09       2호선   201            시청   709244   663498
# 11   2019-09       2호선   202         을지로입구  1449151  1441621
# 12   2019-09       2호선   203         을지로3가   651937   646804
# 13   2019-09       2호선   204         을지로4가   351620   352390
# ...
