# %%
# %matplotlib notebook

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('subwayfee.csv',encoding='euc-kr')
df=data[['호선명','지하철역','무임승차','무임하차']]

ddf = data.groupby('호선명').sum()
sdf = df[df['무임승차']==df['무임승차'].max()]
sdf[['호선명','지하철역','무임승차']]#무임승차 최대값
# Out:
#    호선명  지하철역    무임승차
# 3  1호선  종로3가  357984

# %%
hdf = df[df['무임하차']==df['무임하차'].max()]
hdf[['호선명','지하철역','무임승차']]#무임하차 최대값
# Out:
#    호선명 지하철역    무임승차
# 7  1호선  제기동  332466

# %%
df['무임승차']
# Out:
# 0      210484
# 1      104482
# 2      151384
# 3      357984
# 4      260406
# 5      128585
# 6      117901
# 7      332466
# 8      311691
# 9      145778
# 10      58994
# 11     113731
# 12      86211
# 13      84437
# 14      55634
# 15      98569
# 16      66047
# 17      56989
# 18      14566
# 19      60797
# 20     101162
# 21      93845
# 22     103966
# 23     141369
# 24      86146
# 25     199758
# 26     107923
# 27      54750
# 28     116249
# 29     204140
#         ...
# 567      7667
# 568     36979
# 569     16174
# 570     16482
# 571     24931
# 572     24333
# 573     22949
# 574     47066
# 575     17488
# 576     29845
# 577     30288
# 578     28005
# 579     22353
# 580     13477
# 581     19034
# 582      5954
# 583     63654
# 584     33743
# 585     27415
# 586     31068
# 587     45130
# 588     40135
# 589     26059
# 590     35035
# 591     35598
# 592     39899
# 593     43454
# 594     31089
# 595     15254
# 596     22150
# ...

# %%
mg=df['무임승차']
plt.pie(mg)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x25c03a754a8>,
# ...
#  [Text(1.0998017410030072, 0.020883737375154067, ''),
#   Text(1.0987646521564742, 0.052117551472246476, ''),
#   Text(1.097269253194903, 0.07746086749514183, ''),
#   Text(1.092553417673318, 0.1277772653109799, ''),
#   Text(1.0837302914020825, 0.18849046526961868, ''),
#   Text(1.0764507730731727, 0.22639287345269726, ''),
#   Text(1.071151543481102, 0.2502685975068644, ''),
#   Text(1.0601035082451775, 0.2935652428443585, ''),
#   Text(1.0412664077979688, 0.35463258168351436, ''),
#   Text(1.025750149073525, 0.3972865863273533, ''),
#   Text(1.0182372613518762, 0.4161644862246553, ''),
#   Text(1.0116299424273099, 0.43197784617329377, ''),
#   Text(1.003674931998463, 0.45015178648749216, ''),
#   Text(0.9966271062937817, 0.46554743152602984, ''),
#   Text(0.9906655821079835, 0.4781021903596033, ''),
#   Text(0.9839197412678163, 0.4918352800923025, ''),
# ...

# %%
fig=plt.figure()
mg=ddf['무임승차']
plt.pie(mg,autopct='%1.1f%%')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x25c046b32e8>,
# ...
#  [Text(1.0799261958727142, 0.20918750313507856, ''),
#   Text(0.7369580631188238, 0.816635055091411, ''),
#   Text(0.034044233811718956, 1.099473051122297, ''),
#   Text(-0.4868289858923254, 0.9864063759399826, ''),
#   Text(-0.9082061921829787, 0.6206138191182135, ''),
#   Text(-1.0840947291413594, 0.1863829880861517, ''),
#   Text(-1.0605946575042169, -0.29178583322963647, ''),
#   Text(-0.8810053835640967, -0.658657357152472, ''),
#   Text(-0.7413806688799727, -0.8126221162453582, ''),
#   Text(-0.6302550859713457, -0.9015423043913424, ''),
#   Text(-0.5908566047623661, -0.9278407582169956, ''),
#   Text(-0.39936398245209304, -1.0249431250171905, ''),
#   Text(-0.040983357685673204, -1.0992362641365179, ''),
#   Text(0.18127333676484347, -1.0849608183608013, ''),
#   Text(0.40785633205167726, -1.0215934672879188, ''),
#   Text(0.5924299949082158, -0.9268369334101073, ''),
# ...

# %%
fig=plt.figure()
hg=df['무임하차']
plt.pie(hg)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x25c0559c5f8>,
# ...
#  [Text(1.0998109591273433, 0.020392503117403656, ''),
#   Text(1.0988002441802098, 0.051361691848219926, ''),
#   Text(1.097356385712926, 0.07621655158208057, ''),
#   Text(1.0929971776446215, 0.12392404795233321, ''),
#   Text(1.0848403101673287, 0.18199313568388864, ''),
#   Text(1.0778293318539167, 0.2197360493759262, ''),
#   Text(1.0726481898233151, 0.24377420058071217, ''),
#   Text(1.0612527100838163, 0.28938328448574113, ''),
#   Text(1.0413745765148126, 0.35431481960058486, ''),
#   Text(1.025301491174686, 0.3984430350689611, ''),
#   Text(1.0178118475998987, 0.41720383853133575, ''),
#   Text(1.0116564576997538, 0.4319157459440283, ''),
#   Text(1.0039934564504573, 0.4494409187030747, ''),
#   Text(0.9970356598107518, 0.46467181221345777, ''),
#   Text(0.9909646604881373, 0.4774819804596095, ''),
#   Text(0.9838733386230155, 0.49192809794399955, ''),
# ...

# %%
fig=plt.figure()
hg=ddf['무임승차']
plt.pie(hg,autopct='%1.1f%%')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x25c071ad320>,
# ...
#  [Text(1.0799261958727142, 0.20918750313507856, ''),
#   Text(0.7369580631188238, 0.816635055091411, ''),
#   Text(0.034044233811718956, 1.099473051122297, ''),
#   Text(-0.4868289858923254, 0.9864063759399826, ''),
#   Text(-0.9082061921829787, 0.6206138191182135, ''),
#   Text(-1.0840947291413594, 0.1863829880861517, ''),
#   Text(-1.0605946575042169, -0.29178583322963647, ''),
#   Text(-0.8810053835640967, -0.658657357152472, ''),
#   Text(-0.7413806688799727, -0.8126221162453582, ''),
#   Text(-0.6302550859713457, -0.9015423043913424, ''),
#   Text(-0.5908566047623661, -0.9278407582169956, ''),
#   Text(-0.39936398245209304, -1.0249431250171905, ''),
#   Text(-0.040983357685673204, -1.0992362641365179, ''),
#   Text(0.18127333676484347, -1.0849608183608013, ''),
#   Text(0.40785633205167726, -1.0215934672879188, ''),
#   Text(0.5924299949082158, -0.9268369334101073, ''),
# ...
